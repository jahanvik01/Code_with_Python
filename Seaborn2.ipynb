# %% [markdown]
# # Scatter Plot

# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

df = sns.load_dataset("exercise")
df.head()
# Out:
#    Unnamed: 0  id     diet  pulse    time  kind
# 0           0   1  low fat     85   1 min  rest
# 1           1   1  low fat     85  15 min  rest
# 2           2   1  low fat     88  30 min  rest
# 3           3   2  low fat     90   1 min  rest
# 4           4   2  low fat     92  15 min  rest

# %%
plt.figure(figsize=(5, 3))
sns.scatterplot(x = "time", y = "pulse", data = df, )
plt.show()

# %%
df = sns.load_dataset("fmri")

sns.scatterplot(x="timepoint", y="signal", data=df, marker='+')
plt.grid(alpha=0.5)
plt.show()

# %%
sns.scatterplot(x="timepoint", y="signal", hue="region", data=fmri, palette='bwr')
plt.grid(axis='y', alpha=0.3)
plt.show()

# %% [markdown]
# # Heatmap

# %%
df=sns.load_dataset("iris")
# df.head()

plt.figure(figsize=(5, 4))
sns.heatmap(data, cmap="bwr_r", annot=True, xticklabels = False, yticklabels = False, cbar=False)
plt.show()

# %% [markdown]
# # Pair plot

# %%
df=sns.load_dataset("iris")
# df.head()

sns.pairplot(data=df, hue="species", palette="spring", height=1.5, diag_kind="kde")
plt.show()

# %% [markdown]
# # Cat plot

# %%
df=sns.load_dataset("tips")
sns.catplot(x="sex", y="tip", data=df, palette="GnBu", hue="smoker", col="day", height=2)
plt.show()

# %%
df = sns.load_dataset("exercise") 

plt.figure(figsize=(4, 3))
sns.catplot(x="time", y="pulse", hue="kind", data=df)
plt.show()

# %%
sns.catplot(x="time", y="pulse", hue="kind", col="diet", data=df)
plt.show()

# %%
df=sns.load_dataset("tips")
sns.catplot(x="sex", y="tip", data=df, palette="GnBu", hue="smoker", col="day", height=2)
plt.show()

# %%
ds = sns.load_dataset("titanic") 
sns.catplot(x="alive", col="deck", col_wrap=4, data=ds, kind="count", height=2.5, palette='GnBu', aspect=.7)
plt.show()
# Out:
# C:\Users\missj\AppData\Local\Temp\ipykernel_15708\2484234643.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.catplot(x="alive", col="deck", col_wrap=4, data=ds, kind="count", height=2.5, palette='GnBu', aspect=.7)
