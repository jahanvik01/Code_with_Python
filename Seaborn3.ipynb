# %% [markdown]
# # FacetGrid

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

df = sns.load_dataset('tips')

#scatter plot

mp = sns.FacetGrid(df, col='sex', hue='day')
mp.map(sns.scatterplot, 'total_bill', 'tip')
mp.add_legend()
plt.show()

# %%
#Bar plot

mp = sns.FacetGrid(df, col='day')
mp.map(sns.barplot, 'sex', 'tip', order=['Male', 'Female'], color= 'pink')
plt.show()

# %%
#Hist plot

mp = sns.FacetGrid(df, row ='smoker', col ='time')  
mp.map(plt.hist, 'total_bill', bins = 10, color='grey', alpha=0.8, edgecolor='blue') 
plt.show()

# %%
#Regression plot

mp = sns.FacetGrid(df, col ='time', hue ='smoker') 
mp.map(sns.regplot, "total_bill", "tip") 
mp.add_legend()
plt.show()

# %%
mp = sns.PairGrid(df, hue='time') 
mp.map_diag(sns.histplot)
mp.map_offdiag(sns.scatterplot)
plt.show()

# %%
mp = sns.FacetGrid(df, col ='time') 
mp.map(sns.kdeplot, 'tip') 
plt.show()

# %% [markdown]
# # Kernel Density Estimation (KDE) plot

# %%
df = sns.load_dataset('tips')

plt.figure(figsize=(5, 3))
sns.kdeplot(y='total_bill', data = df)
plt.show()

# %%
plt.figure(figsize=(5, 3))
sns.kdeplot(x='size', hue='day', data = df)
plt.show()

# %%
plt.figure(figsize=(5, 3))
sns.kdeplot(x='tip', hue='day', fill=True, data = df)
plt.show()

# %%
plt.figure(figsize=(5, 3))
sns.kdeplot(x='total_bill', y='tip', data = df)
plt.show()

# %%
plt.figure(figsize=(5, 3))
sns.kdeplot(x='total_bill', y='tip', fill=True, cmap='GnBu', data = df)
plt.show()

# %%
df = sns.load_dataset('iris')
df.head()
# df.tail()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
s = df.loc[df.species=='setosa']
v = df.loc[df.species=='virginica']

plt.figure(figsize=(5, 3))
sns.kdeplot(x=s.sepal_width, y=s.petal_width, data=df)
plt.show()

# %%
plt.figure(figsize=(5, 3))
sns.kdeplot(x=v.sepal_width, y=v.petal_width, data=df, fill=True)
plt.show()

# %% [markdown]
# # Relational plot

# %%
df= sns.load_dataset("tips")

sns.relplot(data= df, x="tip", y="total_bill", hue="sex", kind="line", col="time")
plt.show()

# %% [markdown]
# # Group by function

# %%
data= pd.read_excel("employee.xlsx")
#print(data)

gp= data.groupby("Department").agg({"Annual Salary (in Rs.)":"mean"})
sns.heatmap(data= gp)
plt.show()

# %%
data= pd.read_excel("car_data.xlsx")
#print(data)

gp= data.groupby("owner").agg({"selling_price":"sum"})
sns.heatmap(data= gp, cmap="YlGnBu") 
plt.show()
